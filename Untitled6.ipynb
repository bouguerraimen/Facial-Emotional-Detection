# %% [markdown]
# <a href="https://colab.research.google.com/github/bouguerraimen/Facial-Emotional-Detection/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi
# Out:
# Mon Oct 20 20:05:14 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
! pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.7/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="FSsyqqq2L2hwNZaaQaX6")
project = rf.workspace("workenv-dayet").project("facial-emotion-dataset-7g1jd-hipbk")
version = project.version(3)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/content/Facial-Emotion-Dataset--3'

# %%
! yolo  task=detect mode=train  data={dataset.location}/data.yaml model="yolo11n.pt" epochs=30 imgsz=640
# Out:
# ...
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
Image("/content/runs/detect/train/confusion_matrix.png",width=600)

# %%
Image("/content/runs/detect/train/labels.jpg",width=600)

# %%
Image("/content/runs/detect/train/results.png",width=600)

# %%
Image("/content/runs/detect/train/train_batch0.jpg",width=600)

# %%
! yolo  task=detect mode=val  data={dataset.location}/data.yaml
# Out:
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1512.9±768.9 MB/s, size: 36.7 KB)
# val: Scanning /content/Facial-Emotion-Dataset--3/valid/labels.cache... 185 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 185/185 3.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 12/12 3.2it/s 3.8s
#                    all        185        862      0.886       0.11     0.0736      0.041
#                 person         76        176      0.199      0.767      0.225      0.106
#                bicycle         18         18          1          0      0.106     0.0744
#                    car         51        128          1          0          0          0
#             motorcycle         64        180          1          0          0          0
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train/weights/best.pt" conf=0.25 source={dataset.location}/test/images  save=True
# Out:
# Ultralytics 8.3.218 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,517 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/99 /content/Facial-Emotion-Dataset--3/test/images/1-5-_jpg.rf.fedd78c04d11645905c4124fa52aaa17.jpg: 640x640 1 angry, 1 sad, 15.5ms
# image 2/99 /content/Facial-Emotion-Dataset--3/test/images/1-7-_jpg.rf.e66429ccfa57cb2c03c5e06fe43e3a8b.jpg: 640x640 1 happy, 7.9ms
# image 3/99 /content/Facial-Emotion-Dataset--3/test/images/1-8-_jpg.rf.d4579ef9e8b6ca750aa61bd65ff33b47.jpg: 640x640 1 happy, 7.9ms
# image 4/99 /content/Facial-Emotion-Dataset--3/test/images/10_jpg.rf.ce00a096968d9ce9ceb0a85b39e601cb.jpg: 640x640 1 angry, 3 fears, 5 happys, 8 neutrals, 4 sads, 7.9ms
# image 5/99 /content/Facial-Emotion-Dataset--3/test/images/14_jpg.rf.26f69d5d4bfeffe1665b1558c11f95e9.jpg: 640x640 1 angry, 10 fears, 2 happys, 4 neutrals, 2 sads, 7.9ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)
for img in glob.glob(f'{latest_folder}/*.jpg')[1:4]:
    display(IPyImage(filename=img, width=600))
    print("\n")
